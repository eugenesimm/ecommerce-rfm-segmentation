# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import seaborn as sns
import matplotlib.pyplot as plt

# %%
rfm = pd.read_csv("../data/rfm_data.csv")
rfm.head()
# Out:
#                  customer_unique_id first_order_date  recency_days  frequency  \
# 0  0000366f3b9a7992bf8c76cfdf3221e2       2018-05-10           111          1
# 1  0000b849f77a49e4a4ce2b2a4ca5be3f       2018-05-07           114          1
# 2  0000f46a3911fa3c0805444483337064       2017-03-10           537          1
# 3  0000f6ccb0745a6a4b88665a16c9f078       2017-10-12           321          1
# 4  0004aac84e0df4da2b147fca70cf8255       2017-11-14           288          1
#
#    monetary
# 0    141.90
# 1     27.19
# 2     86.22
# 3     43.62
# 4    196.89

# %%
required_cols = ["customer_unique_id", "recency_days", "frequency", "monetary"]
missing = [c for c in required_cols if c not in rfm.columns]
if missing:
    raise ValueError(f"Missing columns: {missing}")

#Log transform skewed features

rfm["frequency_log"] = np.log1p(rfm["frequency"])
rfm["monetary_log"]  = np.log1p(rfm["monetary"])

# Recency stays as-is (common practice)
X = rfm[["recency_days", "frequency_log", "monetary_log"]].copy()

# Scales features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
sil_scores = {}
for k in range(2, 7):
    km = KMeans(n_clusters=k, n_init=10, random_state=42)
    labels = km.fit_predict(X_scaled)
    sil_scores[k] = silhouette_score(X_scaled, labels)

print("Silhouette scores by k:")
for k, s in sil_scores.items():
    print(f"k={k}: {s:.4f}")

# Choose k:
best_k = max(sil_scores, key=sil_scores.get)
print("Best k by silhouette:", best_k)
# Out:
# Silhouette scores by k:
# k=2: 0.7082
# k=3: 0.3577
# k=4: 0.3693
# k=5: 0.3545
# k=6: 0.3445
# Best k by silhouette: 2

# %% [markdown]
# Let's look for elbow method too

# %%
wcss = []
for i in range(1, 11):
    # Initialize KMeans
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    # Fit to the features
    kmeans.fit(X_scaled)
    # Append the WCSS
    wcss.append(kmeans.inertia_) 

# Plot the results onto a line graph
plt.figure(figsize=(8, 5))
plt.plot(range(1, 11), wcss, marker='o', linestyle='--')
plt.title('Elbow Method')
plt.xlabel('Number of clusters (K)')
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# While the silhouette score peaked at k=2, this primarily reflected a coarse split between high-value customers and the rest.
# The elbow method indicated diminishing returns beyond k=4, and k=4 enabled more actionable customer segments (VIP, Loyal, At-Risk, Low-Value), which aligned better with business objectives.

# %%
k = 4

# Initialize KMeans with the chosen number of clusters
kmeans = KMeans(n_clusters=k, n_init=50, random_state=42)

# Fit the model to the data and predict the cluster assignments
rfm["cluster"] = kmeans.fit_predict(X_scaled)

# Create Kmeans cluster profile
k_profile = (
    rfm
    .groupby("cluster")
    .agg(
      customers=("customer_unique_id", "count"),
      avg_recency=("recency_days", "mean"),
      avg_frequency=("frequency", "mean"),
      avg_monetary=("monetary", "mean"),
      total_revenue=("monetary", "sum")
    )
    .reset_index()
)

k_profile['customer_share'] = k_profile['customers'] / k_profile['customers'].sum()
k_profile['revenue_share'] = k_profile['total_revenue'] / k_profile['total_revenue'].sum()


k_profile.sort_values('revenue_share', ascending=False)

k_profile
# Out:
#    cluster  customers  avg_recency  avg_frequency  avg_monetary  \
# 0        0      26904   425.232716       1.000000    118.741643
# 1        1      35866   146.889422       1.000000     69.449730
# 2        2      27787   174.400619       1.000000    319.307423
# 3        3       2801   219.809354       2.113888    308.588794
#
#    total_revenue  customer_share  revenue_share
# 0   3.194625e+06        0.288181       0.207141
# 1   2.490884e+06        0.384177       0.161510
# 2   8.872595e+06        0.297639       0.575303
# 3   8.643572e+05        0.030003       0.056045

# %% [markdown]
# We can observe that it is ambiguous to classify the clusters in to four segments: VIP, loyal, at-risk, low value. Instead, I clssifed into three segments: VIP, repeat buyers, and one-time buyers.

# %%
# map the segments to the clusters according to the k_profile
cluster_map = {
  0: 'One-time Buyers',
  1: 'One-time Buyers',
  2: 'VIP',
  3: 'Repeat Buyers'
}
rfm['kmeans_segment_3'] = rfm['cluster'].map(cluster_map)
rfm
# Out:
#                      customer_unique_id first_order_date  recency_days  \
# 0      0000366f3b9a7992bf8c76cfdf3221e2       2018-05-10           111
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f       2018-05-07           114
# 2      0000f46a3911fa3c0805444483337064       2017-03-10           537
# 3      0000f6ccb0745a6a4b88665a16c9f078       2017-10-12           321
# 4      0004aac84e0df4da2b147fca70cf8255       2017-11-14           288
# ...                                 ...              ...           ...
# 93353  fffcf5a5ff07b0908bd4e2dbc735a684       2017-06-08           447
# 93354  fffea47cd6d3cc0a88bd621562a9d061       2017-12-10           262
# 93355  ffff371b4d645b6ecea244b27531430a       2017-02-07           568
# 93356  ffff5962728ec6157033ef9805bacc48       2018-05-02           119
# 93357  ffffd2657e2aad2907e67c3e9daecbeb       2017-05-02           484
#
#        frequency  monetary  frequency_log  monetary_log  cluster  \
# 0              1    141.90       0.693147      4.962145        2
# 1              1     27.19       0.693147      3.338967        1
# 2              1     86.22       0.693147      4.468434        0
# 3              1     43.62       0.693147      3.798182        0
# 4              1    196.89       0.693147      5.287711        2
# ...          ...       ...            ...           ...      ...
# 93353          1   2067.42       0.693147      7.634540        2
# 93354          1     84.58       0.693147      4.449452        1
# 93355          1    112.46       0.693147      4.731450        0
# 93356          1    133.69       0.693147      4.902976        2
# 93357          1     71.56       0.693147      4.284414        0
#
#       kmeans_segment_3
# 0                  VIP
# 1      One-time Buyers
# 2      One-time Buyers
# 3      One-time Buyers
# 4                  VIP
# ...                ...
# 93353              VIP
# 93354  One-time Buyers
# 93355  One-time Buyers
# 93356              VIP
# 93357  One-time Buyers
#
# [93358 rows x 9 columns]

# %%
# Rebuild the k=3 sgment profile
k3_profile = (
    rfm
    .groupby('kmeans_segment_3')
    .agg(
      customers=("customer_unique_id", "count"),
      avg_recency=("recency_days", "mean"),
      avg_frequency=("frequency", "mean"),
      avg_monetary=("monetary", "mean"),
      total_revenue=("monetary", "sum")
    )
    .reset_index()
)


k3_profile['customer_share'] = round(k3_profile['customers'] / k3_profile['customers'].sum(), 2)
k3_profile['revenue_share'] = round(k3_profile['total_revenue'] / k3_profile['total_revenue'].sum(), 2)


k3_profile
# Out:
#   kmeans_segment_3  customers  avg_recency  avg_frequency  avg_monetary  \
# 0  One-time Buyers      62770   266.190808       1.000000     90.576855
# 1    Repeat Buyers       2801   219.809354       2.113888    308.588794
# 2              VIP      27787   174.400619       1.000000    319.307423
#
#    total_revenue  customer_share  revenue_share
# 0   5.685509e+06            0.67           0.37
# 1   8.643572e+05            0.03           0.06
# 2   8.872595e+06            0.30           0.58

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(
    data=rfm,
    x='recency_days',
    y='monetary',
    hue='kmeans_segment_3',
    alpha=0.6
)
plt.title('KMeans (3 Segments): Recency vs Monetary')
plt.show()

# %% [markdown]
# While KMeans helped explore the overall customer structure, overlapping clusters limited its direct operational use. I therefore complemented the analysis with a rule-based RFM segmentation, enabling clear and actionable definitions of VIP and At-Risk customers.

# %%
rfm_rb = rfm.copy()

# Recency: Reverse the order since lower is better
rfm_rb['R_score'] = pd.qcut(
    rfm_rb['recency_days'],
    4,
    labels=[4, 3, 2, 1]
).astype(int)

# Frequency
rfm_rb['F_score'] = pd.qcut(
    rfm_rb['frequency'].rank(method='first'),
    4,
    labels=[1, 2, 3, 4]
).astype(int)

# Monetary
rfm_rb['M_score'] = pd.qcut(
    rfm_rb['monetary'],
    4,
    labels=[1, 2, 3, 4]
).astype(int)

rfm_rb['RFM_score'] = (
    rfm_rb['R_score'] +
    rfm_rb['F_score'] +
    rfm_rb['M_score']
)

rfm_rb.head()
# Out:
#                  customer_unique_id first_order_date  recency_days  frequency  \
# 0  0000366f3b9a7992bf8c76cfdf3221e2       2018-05-10           111          1
# 1  0000b849f77a49e4a4ce2b2a4ca5be3f       2018-05-07           114          1
# 2  0000f46a3911fa3c0805444483337064       2017-03-10           537          1
# 3  0000f6ccb0745a6a4b88665a16c9f078       2017-10-12           321          1
# 4  0004aac84e0df4da2b147fca70cf8255       2017-11-14           288          1
#
#    monetary  frequency_log  monetary_log  cluster kmeans_segment_3  R_score  \
# 0    141.90       0.693147      4.962145        2              VIP        4
# 1     27.19       0.693147      3.338967        1  One-time Buyers        4
# 2     86.22       0.693147      4.468434        0  One-time Buyers        1
# 3     43.62       0.693147      3.798182        0  One-time Buyers        2
# 4    196.89       0.693147      5.287711        2              VIP        2
#
#    F_score  M_score  RFM_score
# 0        1        3          8
# 1        1        1          6
# 2        1        2          4
# 3        1        1          4
# 4        1        4          7

# %%
def rfm_segment_3(row):
    if row['R_score'] >= 3 and row['F_score'] >= 3 and row['M_score'] >= 3:
        return 'VIP'
    elif row['R_score'] >= 3:
        return 'Potential'
    else:
        return 'Dormant'

rfm_rb['rfm_segment_3'] = rfm_rb.apply(rfm_segment_3, axis=1)
rfm_rb['rfm_segment_3'].value_counts()

# Calculate the profile of each segment
rb3_profile = (
    rfm_rb
    .groupby('rfm_segment_3')
    .agg(
        customers=('customer_unique_id','count'),
        avg_recency=('recency_days','mean'),
        avg_frequency=('frequency','mean'),
        avg_monetary=('monetary','mean'),
        total_revenue=('monetary','sum')
    )
    .reset_index()
)

rb3_profile['customer_share'] = rb3_profile['customers'] / rb3_profile['customers'].sum()
rb3_profile['revenue_share']  = rb3_profile['total_revenue'] / rb3_profile['total_revenue'].sum()

rb3_profile.sort_values('revenue_share', ascending=False)

rb3_profile
rfm_rb.head()
# Out:
#                  customer_unique_id first_order_date  recency_days  frequency  \
# 0  0000366f3b9a7992bf8c76cfdf3221e2       2018-05-10           111          1
# 1  0000b849f77a49e4a4ce2b2a4ca5be3f       2018-05-07           114          1
# 2  0000f46a3911fa3c0805444483337064       2017-03-10           537          1
# 3  0000f6ccb0745a6a4b88665a16c9f078       2017-10-12           321          1
# 4  0004aac84e0df4da2b147fca70cf8255       2017-11-14           288          1
#
#    monetary  frequency_log  monetary_log  cluster kmeans_segment_3  R_score  \
# 0    141.90       0.693147      4.962145        2              VIP        4
# 1     27.19       0.693147      3.338967        1  One-time Buyers        4
# 2     86.22       0.693147      4.468434        0  One-time Buyers        1
# 3     43.62       0.693147      3.798182        0  One-time Buyers        2
# 4    196.89       0.693147      5.287711        2              VIP        2
#
#    F_score  M_score  RFM_score rfm_segment_3
# 0        1        3          8     Potential
# 1        1        1          6     Potential
# 2        1        2          4       Dormant
# 3        1        1          4       Dormant
# 4        1        4          7       Dormant

# %% [markdown]
# Comparing rule-based segment vs Kmeans clustering-based segment

# %%
compare_count_3 = pd.crosstab(
    rfm_rb['kmeans_segment_3'],
    rfm_rb['rfm_segment_3']
)
compare_count_3
# Out:
# rfm_segment_3     Dormant  Potential   VIP
# kmeans_segment_3
# One-time Buyers     35856      24894  2020
# Repeat Buyers        1258        170  1373
# VIP                  9564       9363  8860

# %%
compare_revenue_3 = pd.pivot_table(
    rfm_rb,
    index='kmeans_segment_3',
    columns='rfm_segment_3',
    values='monetary',
    aggfunc='sum',
    fill_value=0
)

compare_revenue_pct_3 = round(
    compare_revenue_3
    .div(compare_revenue_3.sum(axis=1), axis=0)
    * 100,
    2
)

compare_revenue_3, compare_revenue_pct_3
# Out:
# (rfm_segment_3          Dormant     Potential           VIP
#  kmeans_segment_3
#  One-time Buyers   3.752262e+06  1.693041e+06  2.402067e+05
#  Repeat Buyers     3.784889e+05  1.396482e+04  4.719035e+05
#  VIP               3.506865e+06  2.746192e+06  2.619539e+06,
#  rfm_segment_3     Dormant  Potential    VIP
#  kmeans_segment_3
#  One-time Buyers     66.00      29.78   4.22
#  Repeat Buyers       43.79       1.62  54.60
#  VIP                 39.52      30.95  29.52)

# %% [markdown]
# Given the overlapping clusters and limited interpretability of KMeans,
# rule-based RFM segmentation was selected as the final customer grouping.

# %% [markdown]
# Generating datasets for Tableau

# %%
rfm_results = rfm_rb[[
    "customer_unique_id",
    "recency_days",
    "frequency",
    "monetary",
    "R_score",
    "F_score",
    "M_score",
    "RFM_score",
    "rfm_segment_3",
    "first_order_date"
]].copy()

rfm_results['aov'] = rfm_results['monetary'] / rfm_results['frequency']

rfm_results.to_csv("../data/tableau/rfm_results.csv", index=False)

# %%
rfm_results.head()
# Out:
#                  customer_unique_id  recency_days  frequency  monetary  \
# 0  0000366f3b9a7992bf8c76cfdf3221e2           111          1    141.90
# 1  0000b849f77a49e4a4ce2b2a4ca5be3f           114          1     27.19
# 2  0000f46a3911fa3c0805444483337064           537          1     86.22
# 3  0000f6ccb0745a6a4b88665a16c9f078           321          1     43.62
# 4  0004aac84e0df4da2b147fca70cf8255           288          1    196.89
#
#    R_score  F_score  M_score  RFM_score rfm_segment_3 first_order_date     aov
# 0        4        1        3          8     Potential       2018-05-10  141.90
# 1        4        1        1          6     Potential       2018-05-07   27.19
# 2        1        1        2          4       Dormant       2017-03-10   86.22
# 3        2        1        1          4       Dormant       2017-10-12   43.62
# 4        2        1        4          7       Dormant       2017-11-14  196.89

# %%
daily_revenue_w_category = pd.read_csv("../data/daily_revenue_category_raw.csv")
daily_rev_cat_segment = daily_revenue_w_category.merge(
  rfm_results[['customer_unique_id', 'rfm_segment_3', 'first_order_date']],
  on='customer_unique_id',
  how = 'inner'
)

daily_rev_cat_segment.to_csv("../data/tableau/daily_revenue_with_category.csv", index=False)
